# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ### CLEAN DATA

# %%
reports = pd.read_csv('../data/complete_smell.csv')
reports.head(10)
# Out:
#     EpochTime  skewed_latitude  skewed_longitude  smell_value  \
# 0  1477935134          40.4293          -79.8720            1
# 1  1477935767          40.3624          -79.9749            1
# 2  1477955141          40.3275          -79.9606            1
# 3  1477956180          40.4252          -79.8956            2
# 4  1477956293          40.4237          -79.8964            3
# 5  1477970157          40.3627          -79.9729            3
# 6  1477973293          40.4195          -79.9384            5
# 7  1478001707          40.3974          -80.0416            4
# 8  1478001989          40.4308          -79.9527            2
# 9  1478003840          40.4238          -79.8958            3
#
#     smell_description                                 feelings_symptoms  \
# 0                 NaN                                               NaN
# 1                 NaN                                               NaN
# 2                 NaN                                               NaN
# 3           Woodsmoke                                               NaN
# 4          Wood smoke                                               NaN
# 5         Industrial                                                NaN
# 6         Industrial   Eye irritation, nose burns, headache, woke me up
# 7  Industrial, sulfur                              Congestion, coughing
# 8    Industrial smoke                                               NaN
# 9         Industrial                                                NaN
#
#                                  additional_comments  zipcode
# 0                                                NaN    15221
# 1                                                NaN    15227
# 2                                                NaN    15236
# 3                                                NaN    15218
# 4                                                NaN    15218
# 5  Penrated  the house.  Made me go outside to sm...    15227
# 6  This smell happens often. It's always at night...    15207
# 7                                                NaN    15216
# 8                                                NaN    15213
# 9                                                NaN    15218

# %%
additional_comments = reports['additional_comments'].dropna()

# %%
additional_comments
# Out:
# 5        Penrated  the house.  Made me go outside to sm...
# 6        This smell happens often. It's always at night...
# 11       Noticeable odor of hydrocarbons and tar. Cause...
# 47                                          The air stinks
# 48                                   This smell woke me up
#                                ...
# 93320    Smells like chemicals, almost like paint thinn...
# 93328                                     Usual smell here
# 93336                          Smells like burning plastic
# 93347                                         Strong winds
# 93351    My house is closed up yet here we are. scr*w m...
# Name: additional_comments, Length: 16184, dtype: object

# %%
reports_symptoms_string = reports['feelings_symptoms'].tolist()
reports_symptoms_string = [x for x in reports_symptoms_string if pd.notna(x)]

# %%
reports_smells_string = reports['smell_description'].tolist()
reports_smells_string = [x for x in reports_smells_string if pd.notna(x)]

# %%
reports_smells_string
# Out:
# ['Woodsmoke',
#  'Wood smoke',
#  'Industrial ',
#  'Industrial ',
#  'Industrial, sulfur',
#  'Industrial smoke',
#  'Industrial ',
#  'Coke oven',
#  'Tar and hydrocarbon smell ',
#  'Smell fine',
#  'Industrial',
#  'Industrial',
#  'Industrial ',
#  'Industrial ',
#  'Chemical smell. Like hair dye and rotten eggs.',
#  'Chemical smell. Like hair dye and rotten eggs.',
#  'Chemical smell. Like hair dye and rotten eggs.',
#  'Industrial',
#  'Chemical smell. Like hair dye and rotten eggs.',
#  'Chemical smell. Like hair dye and rotten eggs.',
#  'Industrial',
#  'Industrial',
#  'Industrial irritant',
#  'Chemical smell. Like hair dye and rotten eggs.',
#  'Acrid odor',
#  'Acrid odor',
#  'Acrid odor',
#  'Chemical',
#  'Chemical',
#  'Chemical',
#  'Chemical',
#  'Chemical',
#  'metallic',
#  'Acrid Air Continues To Persist.',
#  'Horrible sulfur smell. VERY strong.',
#  'sulfur',
#  'sulfur',
#  'sulfur',
#  'sulfur',
#  'sulfur',
#  'sulfur',
#  'Coal / Coke',
#  'Industrial, acrid',
#  'Acrid and foul smell ',
#  'Industrial like burning tire',
#  'Not fresh, rotten eggs, hard it identify since it has entered house and we have normalized to it. PM inside is high. Co. Airport reports S winds all night.',
#  'Industrial - sulfur',
#  'Industrial, acrid ',
#  'Coke oven or industrial',
#  'Industrial',
#  'Rotten eggs',
#  'Industrial',
#  'Eggs',
#  'Industrial',
#  'Wow. As bad as I have ever smelled it. Incredibly strong coke plant smell.',
#  'Very strong industrial smell',
#  'Smoke and a little rotten egg',
#  'Industrial, the air is thick with it',
#  'Industrial (coal burning?)',
#  'Industrial (coal burning?)',
#  'Chemical, burning rubber',
#  'Industrial, sulfur',
#  'Industrial, sulfur',
#  'Sulphur egg smell',
#  'Industrial',
#  'Acrid and foul smell',
#  'Industrial',
#  'industrial ',
#  'Steel mill, ugh!',
#  'Super smelly outside',
#  'Industrial like burning tire',
#  'Sulfur',
#  'Sulfer or industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial exhaust',
#  'Coke emissions. very clearly identified. ACHD is not doing nearly enough. ',
#  'Industrial chemicals',
#  'Steel mill, ugh!',
#  'Mill',
#  'Sulfur',
#  'Ash, smoke ',
#  'Sulfur ',
#  'sulfur, choking burning',
#  'fuel',
#  'Acrid industrial smell. ',
#  'Acrid industrial smell. ',
#  'coking, sulfur, acrid ',
#  'Acrid industrial smell. ',
#  'Acrid industrial smell. ',
#  'Industrial or exhaust',
#  'Combination of high sulfur, diesel and humidity make for strong sewage like smell.',
#  'Industrial',
#  'Rotten distinct odor from squirrel hill south at 5:30am',
#  'Sulphur smell',
#  'Industrial',
#  'Industrial acrid',
#  'Awful like smoky and rotten and disgusting ',
#  'Foul, acidic, chronic stench ',
#  'Industrial acrid',
#  'Foul, industrial smell',
#  'Acrid. Reminds me of the smell of a transformer blowing/being struck by lightning with a dose of chemicals. ',
#  'Typical morning in downtown Pittsburgh. Appears to be favorable for inversion conditions.',
#  'Steel mill, ugh!',
#  'Smoky, acrid',
#  'Sulphur',
#  'Sulfur smell',
#  'Rotten eggs',
#  'Foul industrial,  sulfur odor',
#  'Car exhaust and gasoline ',
#  'Industrial like burning tires ',
#  'Rubbery industrial smell',
#  'Factory smell',
#  'Gasoline smell ',
#  'Sulfur',
#  'sewage',
#  'fuel',
#  'Industrial chemical ',
#  'McConway & Torley industrial smell',
#  'Wood smoke',
#  'Industrial',
#  'Industrial ',
#  'Sulfur, Co. Airport winds S 6-7mph',
#  'industrial smell. Dylos at 13,000 for PM2.5!',
#  'Industrial',
#  'Industrial, acrid',
#  'Coal, industrial',
#  'sulphuric smoke',
#  'Industrial exhaust',
#  'Induatrial',
#  'Smoke',
#  'Coke pollution. Dylos at 15,009+',
#  'Sulfur metal industrial ',
#  'Industrial ',
#  'Industrial',
#  'sulfur',
#  'Industrial, sulfur',
#  'acrid industrial coke plant smell. Seems to be Clairton or Edgar Thompson.',
#  'Industrial polution',
#  'Bad odor like sewage not sure',
#  'Industrial',
#  'Industrial, acrid, strong',
#  'Industrial',
#  'Clairton, the gift that keeps on giving.',
#  'Sewage',
#  'Odd',
#  'Industrial, sulfur at 8am',
#  'Sulfur',
#  'Industrial ',
#  'Sulfurous, acrid stench',
#  'sulphuric smoke',
#  'Sulphur',
#  'Sulfur metal industrial. Dylos >2,500. South winds',
#  'Industrial smoke',
#  "acrid, industrial, foul smell. My Awair sensor peaked at 864ppb VOC's this morning at 6:20 AM.",
#  'Coke/industrial pollution smell for a 2nd day in a row and 3rd time in one week. unacceptable. ',
#  'Sulfur, co. airport winds S 4-5mph, particle counts high',
#  'Sulfur',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Sulfur ',
#  'Industrial',
#  'Industrial (coal?)',
#  'Industrial pollution ',
#  'Coal / Coke',
#  'Industrial rotten egg smell',
#  'Industrial, acrid smell. Like burning.',
#  'Sulfur and chemical smell in both Morningside and Aspinwall.',
#  'still bad at 10:30am',
#  'burnt eggs with scorched rubber',
#  'Industrial chemicals ',
#  'Woodsmoke',
#  'sulfur smell this evening. different from this morning. coming from Clairton or Edgar Thompson ',
#  "Sooty, acrid smell, with VOC's over 800ppb and Dylos 0.5 above 5000. The stench leaked into my house last night. Third night in a row!! where can I go for relief??",
#  'Sewage',
#  'burning plastic',
#  'Rotten eggs',
#  'Sewage ',
#  'Diesel emissions from construction vehicles',
#  'Gas?',
#  'Diesel pollution from buses',
#  'Industrial emissions ',
#  'Industrial ',
#  'Massive dust cloud from construction vehivle',
#  'Industrial ',
#  'Industrial emissions ',
#  'Wood smoke',
#  "horribly stinky tonight! VOC's just jumped above 800ppb on my Awair. Strong sulfur smell.",
#  'Wood smoke ',
#  'Smells like sulfer and burning. Has gotten worse in the last few hours.',
#  'Industrial / Coal / Coke',
#  'Industrial ',
#  'industrial sooty, smoky',
#  'Industrial ',
#  'Sulphur',
#  'Industrial',
#  'Industrial',
#  'Sulfur',
#  'Industrial',
#  'Auto exhaust',
#  'Industrial ',
#  'Industrial & lingering exhaust fumes',
#  'Industrial ',
#  'Industrial',
#  'Smoke',
#  'Industrial. Smoke. Sulfur. ',
#  'Rubbery industrial',
#  'Industrial ',
#  'Industrial ',
#  'Burning coal, co airport wind S 8mph',
#  'Sulfur and chemical smell.',
#  'Industrial / Coal / Coke / Diesel',
#  'Heavy sulfur metal. I can also smell it inside Target store. Industrial smell. Acrid. ',
#  'sulfer, eggs',
#  'Industrial sulfur and smoke',
#  'Industrial or burning rubber smell ',
#  'Faint industrial',
#  'Finally, I can go jogging today.',
#  'burning metal ',
#  'Industrial, McConway & Torley, like burning plastic',
#  'Wood smoke',
#  'Industrial, burning rubber smell',
#  'Sulfur hot metal',
#  'Sulfur hot metal',
#  'Industrial ',
#  'Industrial ',
#  'Industrial ',
#  'Industrial ',
#  'Industrial ',
#  'Industrial; from Mcconway torley ',
#  'Industrial metallic',
#  'Industrial metallic',
#  'Industrial metallic',
#  'Industrial metallic',
#  'Rubber or asphalt ',
#  'Burning metal',
#  'Woodsmoke?',
#  'Wood smoke ',
#  'Gasoline',
#  'Visibe dust in air, burning ',
#  'Industrial ',
#  'sewage or fertilizer',
#  'Wood smoke',
#  'Wood smoke',
#  'Sooty sulphur smell, has entered house, winds are SSW last 3 hours. Particle counts high.',
#  'Industrial',
#  'Industrial',
#  'Industrial / Coal / Coke',
#  'Industrial coal smoke smell.',
#  'industrial',
#  'Industrial',
#  'Mill',
#  'Steel mill',
#  'Mill',
#  'Honestly, it smells like brewed cancer!  ',
#  'Honestly, it smells like brewed cancer!  ',
#  'Honestly, it smells like brewed cancer!  ',
#  'Honestly, it smells like brewed cancer!  ',
#  'Honestly, it smells like brewed cancer!  ',
#  'Honestly, it smells like brewed cancer!  ',
#  'Honestly, it smells like brewed cancer!  ',
#  'Woodsmoke, fall leaves? Faint.',
#  'Wood smoke.',
#  "Sulfur, rotten eggs. VOC's are up at 766 ppb and rising! Very low mixing height of 200ft.",
#  'Wood smoke',
#  'Chemical, foul smell',
#  'Acrid coal smoke; very strong.',
#  'Acrid industrial stench',
#  'Coal, winds S 9mph, particle counts high',
#  'Industrial pollution',
#  'Industrial / Coke / Coal',
#  'Industrial, sulfur',
#  'Industrial. Sulfur. ',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'smoke',
#  'Sulphur ',
#  'Horrible stench this morning. Acrid, coke plant industrial smell. 13,000 pm0.5 readings on the Dylos, and Awair VOC levels above 1000. Totally unacceptable. Totally predictable. ',
#  'Horrible stench this morning. Acrid, coke plant industrial smell. 13,000 pm0.5 readings on the Dylos, and Awair VOC levels above 1000. Totally unacceptable. Totally predictable. ',
#  'Horrible stench this morning. Acrid, coke plant industrial smell. 13,000 pm0.5 readings on the Dylos, and Awair VOC levels above 1000. Totally unacceptable. Totally predictable. ',
#  'Acrid industrial coke plant smell.',
#  'Acrid industrial coke plant smell.',
#  'Industrial ',
#  'Industrial',
#  'Industrial ',
#  'Industrial ',
#  'Industrial ',
#  'Industrial ',
#  'Rotten eggs',
#  'Industrial pollution',
#  'Industrial pollution',
#  'industrial',
#  'Sulfur',
#  'Industrial, chemical',
#  'Smoky, acrid',
#  'Smoky, acrid',
#  'Rotten egg',
#  'Industrial, smoke',
#  'Industrial ',
#  'Kind of sweet.',
#  'Sulfur coal smell persists, wind SSE 10mph, particle counts inside and outside high, CO2 outside oner 600ppm',
#  'Industrial ',
#  'Industrial, rubber',
#  'Strong industrial tar and acrid coke plant smell.',
#  'Burning',
#  'Natural gas',
#  'Industrial',
#  'strange smell. not quite normal Coke smell',
#  'Industrial ',
#  'Industrial coke plant stench. As expected, with mixing height below 200ft and slight wind from the south. Unacceptable!! When will this stench-fest end?!???!?!?',
#  'Industrial, Coal, Coke',
#  'Acrid, smokey - detected same odor at 5.45am. Earlier odor was stronger.',
#  'High VOC levels all night long. Acrid industrial coke plant smell. Over 7000 pm0.5 on Dylos monitor.',
#  'Industrial',
#  'Industrial. ',
#  'Industrial',
#  'sulphuric smoke',
#  'Foul, industrial, chemical stink',
#  'Burnt rubber',
#  'Industrial',
#  'Industrial',
#  'Industrial toxins',
#  'Acrid industrial. Dylos pm0.5 is now above 9000.',
#  'Industrial ',
#  'Industrial, Rotten eggs',
#  'Strong industrial acrid coal stink',
#  'Industrial',
#  'Industrial ',
#  'Strong acrid smell, kind of like burning tar. Co airport winds generally S 3-6mph. Particle counts elevated since midnight.',
#  'Industrial, acrid, like grinding metal',
#  'Sulfur like, industrial smell',
#  'industrial ',
#  'Industrial coal smell',
#  'Industrial chemical ',
#  'Industrial. Sulfur ',
#  'Industrial. Sulfur ',
#  'Diesel fumes, exhaust',
#  'Sulfur like ',
#  'Eggs/sewer',
#  'Acrid industrial stink just started up. Wind speed and direction and mixing height indicate to me that the stench will persist all night. It makes me angry that have to report this stuff so often without resolution. It has been going on like this for years!!!',
#  'smells like metal acrid',
#  'Acrid coal smoke smell',
#  'Rotten eggs, maybe sewer gas',
#  'Burning sulphur smell',
#  'Pollution ',
#  'Acrid sulfur, winds out of S, particle counts very high inside and out',
#  'Industrial, Coke, Coal',
#  'Rotten egg, sulfur smell with some fuel smells mixed in.',
#  'Coke pollution',
#  'Fourth night in a row. Acrid industrial smell has been going on all night long.',
#  'usual sulfur smoke ',
#  'Industrial steel mill ',
#  'Industrial, wood',
#  'Industrial AGAIN!!',
#  'Industrial',
#  'Sewage',
#  'Industrial ',
#  'Industrial ',
#  'coke',
#  'Rotten egg',
#  'Strong smokey acrid air continues.',
#  'Industrial',
#  'Fire and brimstone',
#  'Exhaust',
#  'Wood smoke',
#  'Burning',
#  'Industrial metallic ',
#  'Rotten eggs',
#  'McConway & Torley, industrial, burning metal',
#  'Skunk ',
#  'Can smell sulfur on first floor and outside. Heavy fog. Particle counts definitely elevated on first floor and outside warmed air samples.',
#  'Industrial, sulfur',
#  'Industrial..rubber burning',
#  'Industrial ',
#  'industrial smell. Dylos at 30,000+ (partially due to fog)',
#  "A ripe foul acrid industrial stench. Dylos is at 24,000 and Awair VOC's peaked over 1000ppb last night. This is the fifth night in a row we have had unreasonable stench.",
#  'Industrial, metallic, burning',
#  'sulphuric smoke',
#  'Industrial',
#  'Industrial',
#  'Industrial smrll, similar ti asphalt',
#  'Rotten eggs industrial ',
#  'Industrial, acrid, been very bad since early this morning',
#  'Industrial ',
#  'Metallic and burnt smelling',
#  'Burning tires and overall ugly smell',
#  'sulfur and ammonia',
#  'Industrial',
#  'Industrial',
#  'Industrial ',
#  'Burning metal, industrial',
#  'Sharp, coal tar like',
#  'Industrial ',
#  'Industrial',
#  'Industrial ',
#  'Rotten eggs, industrial',
#  'Indutrial',
#  'Industrial ',
#  'Acrid sulfur smell persists w/fog. Very high particle counts. Indoor counts still rising.',
#  'Industrial steel mill ',
#  'Industrial/chemical',
#  'Strong acrid industrial smell.',
#  'Industrial',
#  'Sulfur smell hanging in the fog. Absolutely disgusting.',
#  'It still stinks to high heaven! Sooty, acrid, industrial. Dylos at 28,000 (possibly partially due to fog)',
#  'eggs',
#  'Industrial. Sulfur',
#  'Sulfur ',
#  'Industrial',
#  'Industrial',
#  'Sulfur and smoke',
#  'construction related',
#  'Industry ',
#  'Industrial',
#  'Industrial sulfur smoke',
#  'Sulfur, fog has burned off but heave blue haze is clearly visible. Dylos readings may be at a two year high.',
#  'Sulfur industrial smoke',
#  'Industrial, sulfurous',
#  'Rotten eggs ',
#  'Smoky ',
#  'Industrial ',
#  'still acrid',
#  'Coal , Coke',
#  'Acrid sulfur',
#  'Smog/sulfur odor',
#  'Industrial',
#  'Exhaust',
#  'Rotten egg',
#  'Industrial',
#  'Chemically',
#  'burning sulfur',
#  'Very bad sulfur-like odor. Sewage-like.',
#  'Sulfur or stink bomb',
#  'Foul rotten egg smell',
#  "Smells like a mix of vomit, fish food, sulfur, and acrid coke plant gasses. Horrific! Awair is over 900ppb for VOC's, Dylos is above 13000!",
#  'Wood smoke',
#  'Industrial and also eggy.',
#  "Acrid, industrial, sulfur. VOC's exceeded 1400ppb last night, over 40%higher than all other nights this week. Extraordinary stink!!!",
#  'Rotten eggs',
#  'Industrial',
#  'Rotten fish, dead animal',
#  'Industrial ',
#  'Chemical- like paint fumes',
#  'Chemical- like paint fumes',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Acrid, rotten',
#  'Industrial ',
#  'Industrial ',
#  'Wood smoke',
#  'Wood smoke',
#  'Wood smoke',
#  'Wood smoke',
#  'Wood smoke',
#  'Industrial ',
#  'Chemical',
#  'Industrial',
#  'Industrial -large cloud of smoke/smog over mconway and torley, diesel - 43rd st concrete, buncher building, and snappers warehouse trucks idling',
#  'Industrial ',
#  'not Coke, but burning smell.',
#  'Industry ',
#  'burning plastic',
#  'Industrial acrid stink.',
#  'Industrial',
#  'Industrial ',
#  'Coal , Coke',
#  'Slight swampy smell. So far much better here than the last number of days.',
#  'Industrial ',
#  'Burnt rubber or onions?',
#  'Very acrid outside. Winds S 9mph.',
#  'Industrial ',
#  'Industrial',
#  'Sulphuric chemical smell again today in Morningside.',
#  'Industrial',
#  'Smells like burning electrical as well as asphalt. ',
#  'Exhaust, cigarettes, and industrial pollution.',
#  'Coal or asphalt burning ',
#  'Paint smell',
#  'Sulfur ',
#  'Industry. M&T foundry',
#  'burning sulfur',
#  'Industrial, foul smell',
#  'Wood smoke',
#  'Wood smoke',
#  'Wood smoke',
#  'Wood smoke',
#  'Wood smoke',
#  'Sulphur',
#  'Paint',
#  'Chemicals and egg smell',
#  'Industrial, rotten egg like',
#  'Rotten eggs',
#  'Rotten eggs',
#  'Woodsmoke and chemicals',
#  'Industrial, rotten-egg smell',
#  "Sulfurous, stinky air and Awair sensor VOC's above 1370ppb, Which is exceptionally high.",
#  'Sulfur like',
#  'Industrial, metallic c',
#  'Industrial ',
#  'Industrial',
#  'Oily industrial smell',
#  'Industrial',
#  'Industrial, sulfer',
#  'Disgusting odor ',
#  'Industrial',
#  'Industrial',
#  'Industrial metal sulfur',
#  'Industrial pollution',
#  'exhaust fumes',
#  'Industrial',
#  'Industrial ',
#  'Diesel exhaust from 20-30 buses',
#  'Woodsmoke.',
#  'Industrial ',
#  'Sulphur',
#  'Noxious, cannot describe. Does not smell like sulfur',
#  'Acrid, industrial smell, entered house. Most noticeable on 1st floor currently. No wind last few hours. Plumage evident by elevated particle counts. CO2 sharply higher.',
#  'Sulfuric',
#  'Sulfuric',
#  'Sulfuric',
#  'Sulfuric',
#  'Sulfuric',
#  'Sulfuric',
#  'horrible sulfur smell. woke me up in the middle of the night.',
#  'Burnt stuff',
#  'Burnt stuff',
#  'Burnt stuff',
#  'Burnt stuff',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Burnt chemicals',
#  'Industrial',
#  'Burnt chemical smell',
#  'Burnt chemical smell',
#  'Burnt chemical smell',
#  'Burnt chemical smell',
#  'Burnt chemical smell',
#  'Burnt chemical smell',
#  'Burnt chemical smell',
#  'Rotten eggs / gas',
#  'Rotten eggs / gas',
#  'Wood smoke. ',
#  'Somewhat like rotten eggs',
#  'Industrial, sulphuric.',
#  'wood smoke',
#  'Plaster',
#  'Sulphur smell',
#  'Industrial',
#  'Excessive woodsmoke',
#  'Electrical burning ',
#  'Like sh*t',
#  'Industrial ',
#  'Phosphorus ',
#  'Industrial.  Smokey oil burning smell.  Very strong.  Woke me out of sleep.',
#  'Industrial',
#  'Industrial ',
#  'Smells like machine oil',
#  'Sooty. Sensors indicate that it was much worse overnight. Not acceptable!',
#  'very chemical smell. industrial pollution + sickly sweet burning plastic smell. ',
#  'Industrial ',
#  'sulfur, burning, pittsburgh',
#  'Industrial',
#  'Phosphorus?',
#  'Industrial',
#  'Industrial ',
#  'Industrial ',
#  'Oil smoke. Industrial burning. ',
#  'Chemical',
#  'Industrial',
#  'Sulphurous',
#  'Sulfur',
#  'Wood smoke ',
#  'Industrial',
#  'Smells diesel like. Winds generally SSE at Co. airport but very still here. Particle counts somewhat elevated but CO2 has remained high through out night.',
#  'Industrial, rotten eggs',
#  'Industrial',
#  'Industrial emissions ',
#  'Industrial',
#  'Industrial',
#  'Industrial ',
#  'Industrial and sulfur',
#  'Industrial',
#  'Industrial',
#  'Heavy exhaust smell',
#  'Industrial',
#  'Acrid industrial, like coal or coke plant smell',
#  'Acrid, industrial',
#  'Sulfur industrial',
#  'sewage',
#  'sewage',
#  'Sufurous',
#  'Industrial, like a coke facility ',
#  'Industrial - sulfur',
#  'Industrial',
#  'Mcconley torley',
#  'Acrid last night. ',
#  'Industrial, steel mill ',
#  'Rain with smog ',
#  'Heavy wood smoke. View of Frick Park hillside (1.2mi.) pretty opaque.',
#  'Natural gas',
#  'Rotten',
#  'Industrial',
#  'Sulfur',
#  'Rotten',
#  'Very, very strong sulfur ofor',
#  'Industrial',
#  'Sulphur and diesel eggs  acrid burning',
#  'Industrial',
#  'Rotten eggs',
#  'It smells a little bit like either p**p or sulfur',
#  'Industrial',
#  'Industrial ',
#  'Industrial ',
#  'Industrial',
#  'Acrid, industrial, steel plant smell.',
#  'Industrial',
#  'Sulfur-like',
#  'Industrial, rubber burning ',
#  'Industrial, sulfur-y',
#  'Acrid industrial, with a hint of ripe organic or fishy smell.',
#  'Industrial',
#  'Burning sulfur ',
#  'Rotten eggs ',
#  'Skunk',
#  'Sulfur',
#  'Sour gas, industrial smell.',
#  'Rotten, smokey',
#  'Rotten eggs and sewage',
#  'sulfur and sewage cocktail',
#  'Rotten eggs ',
#  'natural gas',
#  'Smells like auto exhaust and ozone',
#  'Industrial',
#  'Woodsmoke. ',
#  'Rotten eggs',
#  'Industrial',
#  'burning/pollution',
#  'Industrial',
#  'Rotten - egg, sulfur smell',
#  'Industrial',
#  'Sulfur, burning chemical smell',
#  'Industrial ',
#  'Rotten eggs/industrial ',
#  'Industrial',
#  'Egg',
#  'Rotten, grungy, thick garbage smell.',
#  'Burnt',
#  'Industrial',
#  'Sulfurous ',
#  'Industrial ',
#  'fuel or sulfur',
#  'fuel or sulfur',
#  'Vehicles ',
#  'Sulfur like smell',
#  'Smoke, automobile',
#  'Smoky! ',
#  'Industrial',
#  'Rotten eggs',
#  'Industrial',
#  'Sulfuric',
#  'Sulfuric',
#  'Industrial rotten eggs',
#  'Industrial',
#  'Diesel emissions ',
#  'Industrial, McConway & Torley',
#  'Industrial ',
#  'Industrial, smoky, stinky, sulfury',
#  'Industrial',
#  'Industrial ',
#  'Sulfur industrial',
#  'Rotten',
#  'Industrial',
#  'Acrid',
#  'Industrial',
#  'Rotten eggs and smoke',
#  'Fire ',
#  'Possibly,  two buses idling on beechwood just south of Forbes.  Odor also extends into Homewood Cemetery. ',
#  'Skunk-like smell',
#  'Sulfur industrial',
#  'Sweet chemical odor',
#  'Sewer ',
#  'Smells like gas',
#  'Metallic, welding smell',
#  'Industrial ',
#  'sewer',
#  'Acidic almost like transformers blew',
#  'Woodsmoke',
#  'Burgers and food',
#  'Strong Oil odor',
#  'Woodsmoke',
#  'Strong sulfur smell. ',
#  'sulfurous',
#  'Industrial',
#  'Coal smoke like',
#  'Car/bus exhaust',
#  'Industrial',
#  'Wood smoke',
#  'Nothing',
#  'Sulfur',
#  "It smells like rotten eggs, it's super foul!",
#  'Metallic, welding ',
#  'Wood smoke',
#  'Industrial, sulfur ',
#  'Started at 5 this morning sulpher',
#  'Industrial',
#  'Smell industrial like the smell from the Coke plant',
#  'Sulfur industry   Southerly winds. ',
#  'Sulfur but very acrid. Winds were SSW but now SSE. PM counts steadily increased overnight, still rising.',
#  'Industrial',
#  'Soot, industrial chemical',
#  'Exhaust ',
#  'Wood smoke',
#  'Acrid and smoky',
#  'Wood smoke - pretty strong this evening.',
#  'Stench, diesel, clutch...slightly sulpher',
#  'Wood smoke',
#  'Industrial rotten eggs ',
#  'Industrial sulfur ',
#  'Industrial, dusty',
#  'Rotten eggs',
#  'Industrial ',
#  'Rotten eggs',
#  'Sulphuric',
#  'Again, the rotten eggs smell... Ruins a beautiful Saturday.....',
#  'Industrial--coke plant and exhaust',
#  'Industrial sulfur',
#  'Industrial.',
#  'Industrial',
#  'Industrial',
#  'Industrial',
#  'Industrial ',
#  'Sulfur industrial   Southerly wind',
#  'Industrial',
#  'Sulfur odor quite strong outside. Can also be smelled indoors',
#  'Horrible industrial smell. Keeps getting worse. Leaking into my house. Feeling trapped! ',
#  'Sulfer',
#  'ET Works sulfur',
#  'Burning sulpher toilet smell',
#  'sulfur and smoke',
#  'Industry',
#  'Rotten eggs',
#  'Industrial and sulfur smell',
#  'Acetone ',
#  'Sulfur ',
#  'Terrible industrial sulphuric smell. Yuck.',
#  'Sulphuric, toxic',
#  'Chemical, leaves a terrible taste in my mouth',
#  'Rotten egg',
#  'Industrial sulfur odor',
#  'Industrial ',
#  'Sulfurous!',
#  'Chemical-like, acid',
#  'Industrial, maybe smoke',
#  'sewage',
#  'Smells like burning plastic.',
#  'Wood smoke...burning plastic smoke....burning garbage',
#  'Musty',
#  'Burning rubber',
#  'Industrial',
#  'Industrial ',
#  'Rotten eggs',
#  'Industrial (Edgar Thompson Works)',
#  'Sulfur',
#  'Woodsmoke ',
#  'Natural gas',
#  'Smells like exhaust fumes blowing in my face - but everywhere',
#  'Sulfurous ',
#  'Industrial ',
#  'Industrial, foundry',
#  'Horrendous burning of plastic or garbage.',
#  'Rotten egg, industrial',
#  'Rotten eggs',
#  'Industrial, Coal, Coke...',
#  'Industrial',
#  'Industrial chemical ',
#  'Industrial ',
#  'Industrial sulphur',
#  'Acrid & smokey',
#  'Industrial, sulfur',
#  'Rotten eggs',
#  'Asphalts ',
#  'Industrial',
#  'Industrial ',
#  'Industrial',
#  'Industrial, very strong stink',
#  'Industrial, very strong stink',
#  'industrial',
#  'Like rotten eggs, ambient, pervasive and persisting over a walk of several blocks.',
#  'Coke',
#  'Sulfur smell infiltrated home around 3:00am. Copious amounts of frost, likely man made. Winds, what little there are, are from the south. CO2 and PM levels high.',
#  'Sulfur and rotten eggs ',
#  'Strong industrial coal smoke smell.',
#  'Industry ',
#  'Indusrial',
#  'Industrial burnt plastic',
#  'Industrial',
#  'Industrial ',
#  'Acrid fog ',
#  "Smoky , sooty, like something's burning",
#  'Industrial stink',
#  'Auto & truck exhaust ',
#  'Smoke',
#  'Woodsmoke',
#  'Horrible sulpher burning smell',
#  'Crude/fossil fuel/exhaust fumes ',
#  'Acrid industrial',
#  'Dirty',
#  'Maybe diesel,  maybe insista. ',
#  'Can clearly pick up on sulfur coal burning smell this afternoon.',
#  'Sulfur ',
#  'Sulfur',
#  'Industrial ',
#  'Burning plastic',
#  'Sulfurous ',
#  'Industrial',
#  'Acrid odor',
#  'Rotten eggs',
#  'Industrial ',
#  'Acrid industrial steel plant smell this afternoon around 3pm.',
#  'Stinky smoke',
#  'Industrial',
#  'Natural gas',
#  'Steel mill smell',
#  'Burning ',
#  'Little congestion',
#  'Dead animal',
#  'Sulphuric and exhaust ',
#  'Industrial',
#  'Claritin Works',
#  'Braddock steel mill',
#  'Clairton',
#  'Sulfur industrial.  Southerly winds. ',
#  'Petrochemical',
#  'Wood smoke',
#  'Burning rubber. Industrial smell.',
#  'Sulfur!',
#  'Industrial',
#  'Industrial mettallix',
#  'Burning platic',
#  'I smelled different things as I walked around my neighborhood including car exhaust and woodsmoke.  ',
#  'Industrial, heavy',
#  'Industrial metallic most likely mconway and torley',
#  'Diesel smell',
#  'Cooking',
#  'Soup!',
#  'Tar or coal',
#  'industrial',
#  'Industrial ',
#  'Industrial ',
#  'rotten eggs',
#  'Airport',
#  'Sulfur smell',
#  'Farty ',
#  'Smells like something burning - like something between a wood fire and a metallic burning smell ',
#  'Natural gas ',
#  'Seems a bit acrid outside and not sure why.',
#  'Burning, melting plastic.',
#  'Woodsmoke',
#  'Industrial. Sulfur. ',
#  'Industrial',
#  'Vehicle exhaust ',
#  'Vehicle exhaust ',
#  'Industrial, oily',
#  'Typical rt 28 31st bridge exhaust',
#  'Strong industrial odor Friday night. ',
#  'Foul acrid odor',
#  'Industrial',
#  'Burning sulpher',
#  'Industrial, metallic ',
#  'Maybe traffic, but traffic is light currently. ',
#  'Industrial, oily',
#  'Industrial',
#  'Sulfur and smoke. ',
#  'Industrial and burning plastic ',
#  'Traffic, diesel exhaust',
#  'Industrial smoke',
#  'Industrial fumes',
#  'Sulfur',
#  'Putrid smell',
#  'Burning sulpher toilet smell...thought my cat made in litter box..nope.  ',
#  'Sulfur, industrial',
#  'Typical low level of traffic exhaust crossing rt 28 and 31st bridge',
#  'sewage',
#  'Slight combustion metallic sulfur smell',
#  'Smoky and sulfurous',
#  'Industrial',
#  'Construction emissions ',
#  'Coal',
#  'Industrial',
#  'Industrial. Burning plastic',
#  'Industrial from coke plant',
#  'Industrial ',
#  'Sewage like but more putrid',
#  'awful!',
#  'Sulfur and industrial ',
#  'Industrial',
#  'Rotten eggs',
#  'Smells like diesel exhaust and burning metal, probably the many idling tractor trailers at intersection.',
#  'Industrial ',
#  'Rotten eggs',
#  'Chemical',
#  'Burnt plastic',
#  'Rotten wgg',
#  'Rotten',
#  'Natural gas',
#  'Burning',
#  'Wood smoke',
#  'Woodsmoke',
#  'Industrial sulfur',
#  'Industrial',
#  'Outside..soooo bad burning sulpher toilet garlic smell',
#  'Rotten eggs ',
#  'Industrial ',
#  'Industrial',
#  'Smoky ',
#  'Smells of diesel emissions. No wind. PM & CO2 levels were high overnight. PM levels have since dropped outside but are still elevated indoors.',
#  'Yuk.',
#  'Industrial ',
#  'Acrid burnt smell ',
#  'Smoke, exhaust',
#  'Industrial ',
#  'Industrial',
#  'Smoky, like something burning',
#  'Sweet sewer smell',
#  'Like a strong putrid skunk',
#  'Sulfer',
#  'Industrial',
#  'Industrial',
#  'Industrial, smokey',
#  'Oil/gas burning or asphalt smell',
#  'Industrial',
#  'industrial',
#  'Rotten egg and smoke',
#  'Rotten eggs ',
#  'Industrial stink',
#  'Industrial smoke',
#  'Industrial from coke plant',
#  'Industrial',
#  'The combination of the light rain and sulfur makes the air smell like a sewer pipe. Day two of inversion continues. PM & CO2 remain elevated.',
#  'Rubbery',
#  'Industrial ',
#  'Industrial coke plant',
#  'Industrial',
#  'HORRIBLE smoky industrial smell. Getting worse.',
#  'Industrial',
#  'Industrial, sulfur',
#  'Industrial fog',
#  'Industrial ',
#  'Sulfur, worst smell in a long time.  ',
#  'Foul smell!',
#  'INTENSE industrial pollution ',
#  'Industrial - J Edgar Thomson Steel or Clairton Coke',
#  'Sulfur',
#  'Industrial',
#  'Sulphuric',
#  'Pungent and thick, very gross ',
#  'Steel mill like back in the day',
#  'Industrial foundry',
#  'Industrial, burning metal',
#  'Lingering burning smell all day?',
#  'Metallic ',
#  'Industrial',
#  'Industrial',
#  'Industrial ',
#  'Exhaust fumes from 43rd Street Concrete trucks.',
#  'Trucks',
#  'Industrial',
#  'Industrial sulphuric smell',
#  'Sulfur',
#  'Industrial ',
#  'sulfer',
#  'Burning rubber',
#  'wood smoke and sulfur',
#  'Sulfur',
#  'Industrial  and sulphur',
#  'Neville chemical',
#  'Chemical industrial smell, very strong',
#  'Exhaust ',
#  'Industrial ',
#  'Rotten eggs',
#  'Industrial exhaust',
#  'Road fumes?',
#  'Rotten eggs, dense evening fog',
#  'Industrial ',
#  'Sulpher smells taking over entire house',
#  ...]

# %% [markdown]
# ### PRIMERA FORMA: Encontrar palabras mas repetidas

# %%
import spacy
from collections import Counter

# Cargar el modelo de lenguaje de spaCy (requiere haber instalado el modelo 'en_core_web_sm')
nlp = spacy.load("en_core_web_sm")

def find_keywords_nlp(smell_list):
    keywords = Counter()

    for smell in smell_list:
        # Tokenizar la cadena de olor usando spaCy
        tokens = nlp(smell.lower())  # Convertir a minúsculas para una coincidencia de casos

        # Lematizar y filtrar los tokens para obtener palabras clave
        for token in tokens:
            # Ignorar los tokens que son signos de puntuación o palabras cortas
            if not token.is_punct and not token.is_stop and len(token.text) > 2:
                # Lematizar el token
                lemma = token.lemma_
                # Agregar el lema a las palabras clave
                keywords[lemma] += 1

    # Obtener las 10 palabras clave más comunes
    top_keywords = keywords.most_common(20)

    return [keyword[0] for keyword in top_keywords]

# %%
keywords = find_keywords_nlp(reports_smells_string)
print(keywords)
# Out:
# ['industrial', 'sulfur', 'egg', 'rotten', 'smell', 'burn', 'chemical', 'like', 'smoke', 'acrid', 'sulphur', 'coke', 'clairton', 'work', 'woodsmoke', 'exhaust', 'steel', 'wood', 'plastic', 'stench', 'air', 'gas', 'rubber', 'burning', 'sewage', 'coal', 'odor', 'stink', 'mill', 'sulfuric', 'pollution', 'toxic', 'sulphuric', 'strong', 'diesel', 'hydrogen', 'dioxide', 'metallic', 'bad', 'fume', 'heavy', 'plant', 'fire', 'metal', 'sulfide', 'tar', 'sulfurous', 'helicopter', 'smoky', 'smog', 'wind', 'irvin', 'industry', 'asphalt', 'thick', 'sulfer', 'smokey', 'tire', 'house', 'fuel', 'oil', 'rot', 'bitter', 'day', 'sewer', 'garbage', 'awful', 'dirty', 'outside', 'emission', 'come', 'usual', 'skunk', 'car', 'high', 'night', 'morning', 'fart', 'horrible', 'sulfate', 'sour', 'allegheny', 'sweet', 'foul', 'clariton', 'stinky', 'n*sty', 'hospital', 'disgusting', 'gasoline', 'trash', 'general', 'poison', 'putrid', 'mix', 'inside', 'sooty', 'natural', 'window', 'agh']

# %%
keywords = find_keywords_nlp(reports_symptoms_string)
print(keywords)
# Out:
# ['headache', 'throat', 'eye', 'irritation', 'sore', 'nose', 'burn', 'cough', 'breathe', 'nausea', 'sinus', 'irritated', 'congestion', 'sleep', 'asthma', 'breath', 'difficulty', 'hard', 'nasal', 'chest', 'breathing', 'wake', 'smell', 'lung', 'scratchy', 'sneeze', 'itchy', 'dry', 'shortness', 'trouble', 'bad', 'runny', 'stuffy', 'air', 'outside', 'window', 'pain', 'night', 'insomnia', 'pressure', 'head', 'watery', 'respiratory', 'anxiety', 'anger', 'feel', 'ache', 'day', 'burning', 'house', 'like', 'taste', 'eyes', 'open', 'issue', 'choke', 'hurt', 'symptom', 'disgust', 'sick', 'sting', 'stomach', 'dizziness', 'inside', 'tightness', 'nostril', 'mouth', 'migraine', 'close', 'fatigue', 'irritate', 'mild', 'sleeplessness', 'nauseous', 'passage', 'problem', 'steel', 'time', 'bother', 'depression', 'nauseate', 'slight', 'health', 'go', 'tight', 'difficult', 'water', 'skin', 'odor', 'gag', 'stink', 'frustration', 'short', 'get', 'drip', 'allergy', 'wheezing', 'pollution', 'swollen', 'baby']

# %% [markdown]
# #### CAP

# %%
def find_keywords_nlp_strings(text_list):
    keywords = Counter()

    for text in text_list:
        # Tokenizar el texto usando spaCy
        doc = nlp(text.lower())  # Convertir a minúsculas para una coincidencia de casos

        # Filtrar sustantivos y sustantivos propios
        for token in doc:
            if token.pos_ in ["NOUN", "PROPN"]:
                # Ignorar stopwords y puntuación
                if not token.is_stop and not token.is_punct:
                    # Contar sustantivos y sustantivos propios que no sean stopwords ni puntuación
                    keywords[token.text] += 1

    # Obtener las 10 palabras clave más comunes
    top_keywords = keywords.most_common(20)
    return [keyword[0] for keyword in top_keywords]

# %%
# Encontrar palabras clave en las cadenas de texto
keywords = find_keywords_nlp_strings(reports_smells_string)
print(keywords)
# Out:
# ['sulfur', 'eggs', 'smell', 'chemical', 'coke', 'clairton', 'smoke', 'sulphur', 'steel', 'acrid', 'wood', 'exhaust', 'egg', 'stench', 'air', 'plastic', 'rubber', 'burning', 'sewage', 'coal']

# %% [markdown]
# ### TERCERA FORMA:

# %%
smell_keywords = {'industrial','sulphur','egg','burning plastic','smoke','woodsmoke','acrid','coke','tar','smog','chemical','sewage','gas','trash','coal'}

# %%
def find_keywords_nlp_strings(text_list):
    keywords = Counter()

    for text in text_list:
        # Tokenizar el texto usando spaCy
        doc = nlp(text.lower())  # Convertir a minúsculas para una coincidencia de casos

        # Filtrar palabras clave relacionadas con olores
        for token in doc:
            # Lematizar el token y filtrar por sustantivos y sustantivos propios
            lemma = token.lemma_
            if lemma in smell_keywords:
                # Contar palabras clave relacionadas con olores
                keywords[lemma] += 1

    # Obtener las 15 palabras clave más comunes
    top_keywords = keywords.most_common(15)
    return [keyword[0] for keyword in top_keywords]

# %%
top_keywords = find_keywords_nlp_strings(reports_smells_string)
print(top_keywords)
# Out:
# ['industrial', 'egg', 'chemical', 'smoke', 'acrid', 'sulphur', 'coke', 'woodsmoke', 'gas', 'sewage', 'coal', 'tar', 'smog', 'trash']
